# %% [markdown]
# <a href="https://colab.research.google.com/github/amanvashisth/Deep-Learning/blob/master/ANN/backpropagation_regtression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]], columns=['cgpa', 'profile_score', 'lpa'])

# %%
df.head()
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
len([2,2,1])
# Out:
# 3

# %%
def initialize_parameters(layers_dims):

  parameters ={}   #Empty dictionary for parameter
  L = len(layers_dims)

  for l in range(1,L): #loop runs from 1 to L-1
    parameters['W'+ str(l)] = np.ones((layers_dims[l-1],layers_dims[l]))*0.1
    parameters['b'+ str(l)] = np.zeros((layers_dims[l], 1))

  return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
#Basic Perceptron Unit

def linear_forward(A_prev, W, b):

  Z = np.dot(W.T, A_prev) + b

  return Z

# %%
L = len(initialize_parameters([2,2,1]))//2
L
# Out:
# 2

# %%
#Forward Propagation
def forward_prop(X, parameters):
  A = X
  L = len(parameters)//2 #Number of layers in neural network

  for l in range(1,L+1):
    A_prev = X # Output of the previous layer becomes input to current layer
    Wl = parameters["W"+str(l)]
    bl = parameters['b'+ str(l)]

    A = linear_forward(A_prev, Wl, bl)

  return A[0][0],A_prev

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = forward_prop(X, parameters)

# %%
y_hat
# Out:
# np.float64(1.6)

# %%
#Update Parameter
def update_parameters(parameters,y, y_hat,A1,X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat)*A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat)*A1[1][0])
  parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
update_parameters(parameters,y,y_hat,A1,X)

# %%
parameters
# Out:
# {'W1': array([[0.10531456, 0.10531456],
#         [0.10531456, 0.10531456]]),
#  'b1': array([[0.00066432],
#         [0.00066432]]),
#  'W2': array([[0.1384],
#         [0.1384]]),
#  'b2': array([[0.1432]])}

# %%
df.shape
# Out:
# (4, 3)

# %%
# epochs implementation

parameters = initialize_parameters([2,2,1])
epochs = 5

for i in range(epochs):
  Loss = []
  for j in range(df.shape[0]):
    X = df[['cgpa', 'profile_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['lpa']].values[j][0]

    # Forward Propagation
    y_hat,A1 = forward_prop(X,parameters)

    # Backpropagation -> Parameters get updated Here
    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append((y-y_hat)**2)

  print('Epoch -',i+1,'Loss -',np.array(Loss).mean())

parameters
# Out:
# Epoch - 1 Loss - 7.205413203742441
# Epoch - 2 Loss - 1.0733686445728834
# Epoch - 3 Loss - 0.9583801635331537
# Epoch - 4 Loss - 0.9721506091746084
# Epoch - 5 Loss - 0.9426118575983916
# {'W1': array([[0.12725374, 0.1655921 ],
#         [0.13084979, 0.18399961]]),
#  'b1': array([[0.00557808],
#         [0.00685475]]),
#  'W2': array([[0.23838014],
#         [0.40037638]]),
#  'b2': array([[0.40226313]])}
